# %%
# Sample results from your similarity engine
candidates = ['John_Doe_CS', 'Jane_Smith_Acc', 'Alex_Dev_Partial']
scores = [94.2, 12.5, 62.8]

plt.figure(figsize=(10, 6))
colors = ['green' if x > 70 else 'orange' if x > 40 else 'red' for x in scores]
plt.barh(candidates, scores, color=colors)

plt.title('Candidate Similarity Match (%)', fontsize=14)
plt.xlabel('Match Percentage', fontsize=12)
plt.xlim(0, 100)
plt.gca().invert_yaxis()  # Best match at the top

# Add percentage labels to bars
for i, v in enumerate(scores):
    plt.text(v + 1, i, f"{v}%", color='black', va='center', fontweight='bold')

# Save to assets
plt.savefig('../assets/similarity_score_chart.png', bbox_inches='tight', dpi=300)
plt.show()
